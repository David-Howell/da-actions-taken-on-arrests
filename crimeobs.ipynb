# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_type_obs = pd.DataFrame(columns={'crime_type', 'dates', 'observations'})

# %%
crime_type_obs
# Out:
# Empty DataFrame
# Columns: [dates, crime_type, observations]
# Index: []

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Crazy stuff', 'being bad']
crime_type_obs
# Out:
#           dates   crime_type observations
# 0  [2011, 2022]  Crazy stuff    being bad

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Assault', 'There was only 1 Misdemeanor Assault case, and it needed further investigation. The Least represented action was Other Action']
crime_type_obs
# Out:
#           dates   crime_type  \
# 0  [2011, 2022]  Crazy stuff
# 1  [2011, 2022]      Assault
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Narcotics', 'DA stopped requesting further investigation on Misdemeanor Narc Arrests mid 2016 after about a year of doing it a lot. And since late 2019 filed almost no charges on Misd.']
crime_type_obs
# Out:
#           dates   crime_type  \
# 0  [2011, 2022]  Crazy stuff
# 1  [2011, 2022]      Assault
# 2  [2011, 2022]    Narcotics
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Burglary', 'Burglary looks like it is discharged more often than the DA does any other action']
crime_type_obs
# Out:
#           dates   crime_type  \
# 0  [2011, 2022]  Crazy stuff
# 1  [2011, 2022]      Assault
# 2  [2011, 2022]    Narcotics
# 3  [2011, 2022]     Burglary
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'DUI', 'Most of the time Misd DUIs are discharged with Charges being filed a good bit as well. While almost all Felony DUIs have charges filed']
crime_type_obs
# Out:
#           dates   crime_type  \
# 0  [2011, 2022]  Crazy stuff
# 1  [2011, 2022]      Assault
# 2  [2011, 2022]    Narcotics
# 3  [2011, 2022]     Burglary
# 4  [2011, 2022]          DUI
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...
# 4  Most of the time Misd DUIs are discharged with...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Assault and Battery', 'most Ass&Bat charges are Felony with most being discharged or referred away and a big gap in Further investigation from mid 2017-2020']
crime_type_obs
# Out:
#           dates           crime_type  \
# 0  [2011, 2022]          Crazy stuff
# 1  [2011, 2022]              Assault
# 2  [2011, 2022]            Narcotics
# 3  [2011, 2022]             Burglary
# 4  [2011, 2022]                  DUI
# 5  [2011, 2022]  Assault and Battery
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...
# 4  Most of the time Misd DUIs are discharged with...
# 5  most Ass&Bat charges are Felony with most bein...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Theft', 'All but 5 Theft cases are Felony with a similar trend of mostly discharged or referred away, and again we see the drop in asking for further investigation since mid 2017']
crime_type_obs
# Out:
#           dates           crime_type  \
# 0  [2011, 2022]          Crazy stuff
# 1  [2011, 2022]              Assault
# 2  [2011, 2022]            Narcotics
# 3  [2011, 2022]             Burglary
# 4  [2011, 2022]                  DUI
# 5  [2011, 2022]  Assault and Battery
# 6  [2011, 2022]                Theft
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...
# 4  Most of the time Misd DUIs are discharged with...
# 5  most Ass&Bat charges are Felony with most bein...
# 6  All but 5 Theft cases are Felony with a simila...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Robbery', 'ALL Robbery is Felony in SF and most get discharged']
crime_type_obs
# Out:
#           dates           crime_type  \
# 0  [2011, 2022]          Crazy stuff
# 1  [2011, 2022]              Assault
# 2  [2011, 2022]            Narcotics
# 3  [2011, 2022]             Burglary
# 4  [2011, 2022]                  DUI
# 5  [2011, 2022]  Assault and Battery
# 6  [2011, 2022]                Theft
# 7  [2011, 2022]              Robbery
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...
# 4  Most of the time Misd DUIs are discharged with...
# 5  most Ass&Bat charges are Felony with most bein...
# 6  All but 5 Theft cases are Felony with a simila...
# 7  ALL Robbery is Felony in SF and most get disch...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Weapons', 'Weapons charges are mostly Felony with a BIG drop in arrests of all kinds in the first half of 2012']
crime_type_obs
# Out:
#           dates           crime_type  \
# 0  [2011, 2022]          Crazy stuff
# 1  [2011, 2022]              Assault
# 2  [2011, 2022]            Narcotics
# 3  [2011, 2022]             Burglary
# 4  [2011, 2022]                  DUI
# 5  [2011, 2022]  Assault and Battery
# 6  [2011, 2022]                Theft
# 7  [2011, 2022]              Robbery
# 8  [2011, 2022]              Weapons
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...
# 4  Most of the time Misd DUIs are discharged with...
# 5  most Ass&Bat charges are Felony with most bein...
# 6  All but 5 Theft cases are Felony with a simila...
# 7  ALL Robbery is Felony in SF and most get disch...
# 8  Weapons charges are mostly Felony with a BIG d...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Motor Vehicle Theft', 'Stealing cars is always a Felony. And is most often Discharged or Referred away']
crime_type_obs
# Out:
#           dates           crime_type  \
# 0  [2011, 2022]          Crazy stuff
# 1  [2011, 2022]              Assault
# 2  [2011, 2022]            Narcotics
# 3  [2011, 2022]             Burglary
# 4  [2011, 2022]                  DUI
# 5  [2011, 2022]  Assault and Battery
# 6  [2011, 2022]                Theft
# 7  [2011, 2022]              Robbery
# 8  [2011, 2022]              Weapons
# 9  [2011, 2022]  Motor Vehicle Theft
#
#                                         observations
# 0                                          being bad
# 1  There was only 1 Misdemeanor Assault case, and...
# 2  DA stopped requesting further investigation on...
# 3  Burglary looks like it is discharged more ofte...
# 4  Most of the time Misd DUIs are discharged with...
# 5  most Ass&Bat charges are Felony with most bein...
# 6  All but 5 Theft cases are Felony with a simila...
# 7  ALL Robbery is Felony in SF and most get disch...
# 8  Weapons charges are mostly Felony with a BIG d...
# ...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Petty Theft', 'If Petty theft is a felony (which it almost never is) they almost always file Charges. Also petty theft almost never needs Further Investigation']
crime_type_obs
# Out:
#            dates           crime_type  \
# 0   [2011, 2022]          Crazy stuff
# 1   [2011, 2022]              Assault
# 2   [2011, 2022]            Narcotics
# 3   [2011, 2022]             Burglary
# 4   [2011, 2022]                  DUI
# 5   [2011, 2022]  Assault and Battery
# 6   [2011, 2022]                Theft
# 7   [2011, 2022]              Robbery
# 8   [2011, 2022]              Weapons
# 9   [2011, 2022]  Motor Vehicle Theft
# 10  [2011, 2022]          Petty Theft
#
#                                          observations
# 0                                           being bad
# 1   There was only 1 Misdemeanor Assault case, and...
# 2   DA stopped requesting further investigation on...
# 3   Burglary looks like it is discharged more ofte...
# 4   Most of the time Misd DUIs are discharged with...
# 5   most Ass&Bat charges are Felony with most bein...
# 6   All but 5 Theft cases are Felony with a simila...
# 7   ALL Robbery is Felony in SF and most get disch...
# ...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Trespassing', 'Trespassing is almost alway a Misd. and since 2017 almost never needs further investigation. Charges are rarely filed and almost always discharged or referred away.']
crime_type_obs
# Out:
#            dates           crime_type  \
# 0   [2011, 2022]          Crazy stuff
# 1   [2011, 2022]              Assault
# 2   [2011, 2022]            Narcotics
# 3   [2011, 2022]             Burglary
# 4   [2011, 2022]                  DUI
# 5   [2011, 2022]  Assault and Battery
# 6   [2011, 2022]                Theft
# 7   [2011, 2022]              Robbery
# 8   [2011, 2022]              Weapons
# 9   [2011, 2022]  Motor Vehicle Theft
# 10  [2011, 2022]          Petty Theft
# 11  [2011, 2022]          Trespassing
#
#                                          observations
# 0                                           being bad
# 1   There was only 1 Misdemeanor Assault case, and...
# 2   DA stopped requesting further investigation on...
# 3   Burglary looks like it is discharged more ofte...
# 4   Most of the time Misd DUIs are discharged with...
# 5   most Ass&Bat charges are Felony with most bein...
# 6   All but 5 Theft cases are Felony with a simila...
# ...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Selected Traffic', 'Traffic is almost always Misd. and almost always Discharged or Referred away. Also, No Further investigation since 2017 ']
crime_type_obs
# Out:
#            dates           crime_type  \
# 0   [2011, 2022]          Crazy stuff
# 1   [2011, 2022]              Assault
# 2   [2011, 2022]            Narcotics
# 3   [2011, 2022]             Burglary
# 4   [2011, 2022]                  DUI
# 5   [2011, 2022]  Assault and Battery
# 6   [2011, 2022]                Theft
# 7   [2011, 2022]              Robbery
# 8   [2011, 2022]              Weapons
# 9   [2011, 2022]  Motor Vehicle Theft
# 10  [2011, 2022]          Petty Theft
# 11  [2011, 2022]          Trespassing
# 12  [2011, 2022]     Selected Traffic
#
#                                          observations
# 0                                           being bad
# 1   There was only 1 Misdemeanor Assault case, and...
# 2   DA stopped requesting further investigation on...
# 3   Burglary looks like it is discharged more ofte...
# 4   Most of the time Misd DUIs are discharged with...
# 5   most Ass&Bat charges are Felony with most bein...
# ...

# %%
crime_type_obs.loc[len(crime_type_obs)] = [['2011', '2022'], 'Marijuana', 'MJ arrests dropped sharply in mid 2017 never needed further investigation since 2017 and no charges have been filed since 2020... except that one guy!']
crime_type_obs
# Out:
#            dates           crime_type  \
# 0   [2011, 2022]          Crazy stuff
# 1   [2011, 2022]              Assault
# 2   [2011, 2022]            Narcotics
# 3   [2011, 2022]             Burglary
# 4   [2011, 2022]                  DUI
# 5   [2011, 2022]  Assault and Battery
# 6   [2011, 2022]                Theft
# 7   [2011, 2022]              Robbery
# 8   [2011, 2022]              Weapons
# 9   [2011, 2022]  Motor Vehicle Theft
# 10  [2011, 2022]          Petty Theft
# 11  [2011, 2022]          Trespassing
# 12  [2011, 2022]     Selected Traffic
# 13  [2011, 2022]            Marijuana
#
#                                          observations
# 0                                           being bad
# 1   There was only 1 Misdemeanor Assault case, and...
# 2   DA stopped requesting further investigation on...
# 3   Burglary looks like it is discharged more ofte...
# 4   Most of the time Misd DUIs are discharged with...
# 5   most Ass&Bat charges are Felony with most bein...
# ...

# %%
crime_type_obs.to_csv('crime_type_obs.csv')
